# %% [markdown]
# ### Implement the Baseline Model - Logistic Regression

# %% [markdown]
# ### 1. Import the python libraries

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.pipeline import Pipeline 
from imblearn.under_sampling import RandomUnderSampler
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
import joblib

# %% [markdown]
# ### 2. Import the data

# %%
train_filepath = '../data/processed/neiss_feature-engineered_train_data.parquet'
eval_filepath = '../data/processed/neiss_feature-engineered_eval_data.parquet'
holdout_filepath =  '../data/processed/neiss_feature-engineered_holdout_data.parquet'

# %%
train_data= pd.read_parquet(train_filepath)
eval_data = pd.read_parquet(eval_filepath)
holdout_data = pd.read_parquet(holdout_filepath)

# %%
train_data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5120468 entries, 6181068 to 3926627
# Data columns (total 100 columns):
#  #   Column                                   Dtype
# ---  ------                                   -----
#  0   cat__Diagnosis_41                        float64
#  1   cat__Diagnosis_42                        float64
#  2   cat__Diagnosis_46                        float64
#  3   cat__Diagnosis_47                        float64
#  4   cat__Diagnosis_48                        float64
#  5   cat__Diagnosis_49                        float64
#  6   cat__Diagnosis_50                        float64
#  7   cat__Diagnosis_51                        float64
#  8   cat__Diagnosis_52                        float64
#  9   cat__Diagnosis_53                        float64
#  10  cat__Diagnosis_54                        float64
#  11  cat__Diagnosis_55                        float64
#  12  cat__Diagnosis_56                        float64
#  13  cat__Diagnosis_57                        float64
#  14  cat__Diagnosis_58                        float64
#  15  cat__Diagnosis_59                        float64
#  16  cat__Diagnosis_60                        float64
#  17  cat__Diagnosis_61                        float64
#  18  cat__Diagnosis_62                        float64
#  19  cat__Diagnosis_63                        float64
#  20  cat__Diagnosis_64                        float64
#  21  cat__Diagnosis_65                        float64
#  22  cat__Diagnosis_66                        float64
#  23  cat__Diagnosis_67                        float64
#  24  cat__Diagnosis_68                        float64
#  25  cat__Diagnosis_69                        float64
#  26  cat__Diagnosis_71                        float64
#  27  cat__Diagnosis_72                        float64
#  28  cat__Diagnosis_73                        float64
#  29  cat__Diagnosis_74                        float64
#  30  cat__Body_Part_0                         float64
#  31  cat__Body_Part_30                        float64
#  32  cat__Body_Part_31                        float64
#  33  cat__Body_Part_32                        float64
#  34  cat__Body_Part_33                        float64
#  35  cat__Body_Part_34                        float64
#  36  cat__Body_Part_35                        float64
#  37  cat__Body_Part_36                        float64
#  38  cat__Body_Part_37                        float64
#  39  cat__Body_Part_38                        float64
#  40  cat__Body_Part_75                        float64
#  41  cat__Body_Part_76                        float64
#  42  cat__Body_Part_77                        float64
#  43  cat__Body_Part_79                        float64
#  44  cat__Body_Part_80                        float64
#  45  cat__Body_Part_81                        float64
#  46  cat__Body_Part_82                        float64
#  47  cat__Body_Part_83                        float64
#  48  cat__Body_Part_84                        float64
#  49  cat__Body_Part_85                        float64
#  50  cat__Body_Part_87                        float64
#  51  cat__Body_Part_88                        float64
#  52  cat__Body_Part_89                        float64
#  53  cat__Body_Part_92                        float64
#  54  cat__Body_Part_93                        float64
#  55  cat__Body_Part_94                        float64
#  56  cat__Location_0                          float64
#  57  cat__Location_1                          float64
#  58  cat__Location_2                          float64
#  59  cat__Location_4                          float64
#  60  cat__Location_5                          float64
#  61  cat__Location_6                          float64
#  62  cat__Location_7                          float64
#  63  cat__Location_8                          float64
#  64  cat__Location_9                          float64
#  65  cat__Body_Part_2_0.0                     float64
#  66  cat__Body_Part_2_30.0                    float64
#  67  cat__Body_Part_2_31.0                    float64
#  68  cat__Body_Part_2_32.0                    float64
#  69  cat__Body_Part_2_33.0                    float64
#  70  cat__Body_Part_2_34.0                    float64
#  71  cat__Body_Part_2_35.0                    float64
#  72  cat__Body_Part_2_36.0                    float64
#  73  cat__Body_Part_2_37.0                    float64
#  74  cat__Body_Part_2_38.0                    float64
#  75  cat__Body_Part_2_75.0                    float64
#  76  cat__Body_Part_2_76.0                    float64
#  77  cat__Body_Part_2_77.0                    float64
#  78  cat__Body_Part_2_79.0                    float64
#  79  cat__Body_Part_2_80.0                    float64
#  80  cat__Body_Part_2_81.0                    float64
#  81  cat__Body_Part_2_82.0                    float64
#  82  cat__Body_Part_2_83.0                    float64
#  83  cat__Body_Part_2_84.0                    float64
#  84  cat__Body_Part_2_85.0                    float64
#  85  cat__Body_Part_2_87.0                    float64
#  86  cat__Body_Part_2_88.0                    float64
#  87  cat__Body_Part_2_89.0                    float64
#  88  cat__Body_Part_2_92.0                    float64
#  89  cat__Body_Part_2_93.0                    float64
#  90  cat__Body_Part_2_94.0                    float64
#  91  cat__Injury_Mechanism_Burn               float64
#  92  cat__Injury_Mechanism_Fall               float64
#  93  cat__Injury_Mechanism_Ingestion/Choking  float64
#  94  cat__Injury_Mechanism_Laceration/Cut     float64
#  95  cat__Injury_Mechanism_Other/Unspecified  float64
#  96  cat__Injury_Mechanism_Struck By          float64
#  97  remainder__Product_1                     float64
#  98  remainder__Age_Scaled                    float64
#  99  Hospitalized                             int64
# dtypes: float64(99), int64(1)
# memory usage: 3.9 GB

# %% [markdown]
# ### 3. Setup the train/evaluation dataset

# %%
X_train = train_data.drop(columns=['Hospitalized'])
y_train = train_data['Hospitalized']
X_eval = eval_data.drop(columns=['Hospitalized'])
y_eval = eval_data['Hospitalized']

# %% [markdown]
# ### 4. Run Logistic Regression with Majority Undersampling technique

# %%
# Define the undersampler
rus = RandomUnderSampler(sampling_strategy='majority', random_state=42)

# Initialize the log reg algorithm
log_reg = LogisticRegression(solver='lbfgs', max_iter=1000, random_state=42)

# Build the pipeline
model_pipeline = Pipeline(steps=[
        ('undersampler', rus),
        ('classifier', log_reg)
    ])

print("Training model (undersampling majority class)...")
# Fit the model on train dataset
model_pipeline.fit(X_train, y_train)
# Out:
# Training model (undersampling majority class)...
# Pipeline(steps=[('undersampler',
#                  RandomUnderSampler(random_state=42,
#                                     sampling_strategy='majority')),
#                 ('classifier',
#                  LogisticRegression(max_iter=1000, random_state=42))])

# %% [markdown]
# ### 5. Evaluate the results

# %%
print("\nEvaluating on Validation (Eval) Set...")
y_pred = model_pipeline.predict(X_eval)

# Print the Results
print("\n--- Confusion Matrix ---")
print(confusion_matrix(y_eval, y_pred))

print("\n--- Classification Report ---")
print(classification_report(y_eval, y_pred))
# Out:
# Evaluating on Validation (Eval) Set...
#
# --- Confusion Matrix ---
# [[783007 214512]
#  [ 18819  80906]]
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            0       0.98      0.78      0.87    997519
#            1       0.27      0.81      0.41     99725
#
#     accuracy                           0.79   1097244
#    macro avg       0.63      0.80      0.64   1097244
# weighted avg       0.91      0.79      0.83   1097244

# %% [markdown]
# ### 6. Draw RUC-AUC Curve

# %%
def plot_single_roc(model_pipeline, X_test, y_test, model_name="Final Champion Model"):
    """
    Calculates probabilities and plots the ROC-AUC curve for a single trained model 
    against the Hold-Out Test dataset.
    """
    print(f"Generating Final ROC-AUC Curve for {model_name}...")
    
    # 1. Get the probability that the patient is in the Positive Class (Hospitalized)
    # .predict_proba() returns [Probability_Released, Probability_Hospitalized]
    # We slice [:, 1] to grab only the Hospitalized probabilities.
    y_prob = model_pipeline.predict_proba(X_test)[:, 1]
    
    # 2. Calculate the False Positive Rate (fpr) and True Positive Rate (tpr)
    fpr, tpr, thresholds = roc_curve(y_test, y_prob)
    
    # 3. Calculate the Area Under the Curve (AUC) score
    roc_auc = auc(fpr, tpr)
    
    # 4. Set up the plotting canvas
    plt.figure(figsize=(8, 6))
    
    # 5. Plot the Model's Curve
    # We use a bold color (like dark orange) to make it pop for presentations
    plt.plot(fpr, tpr, color='darkorange', lw=2.5, 
             label=f'{model_name} (AUC = {roc_auc:.3f})')

    # 6. Plot the "Coin Flip" Baseline (Random Guessing)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', 
             label='Random Guessing (AUC = 0.500)')

    # 7. Format the Graph for Professional Presentation
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (Minor Injuries incorrectly flagged as Severe)', fontsize=12)
    plt.ylabel('True Positive Rate (Severe Injuries correctly flagged)', fontsize=12)
    plt.title(f'Final Evaluation: {model_name} ROC-AUC', fontsize=16, fontweight='bold')
    plt.legend(loc="lower right", fontsize=12)
    plt.grid(alpha=0.3)
    
    # 8. Display the Graph
    plt.tight_layout()
    plt.show()

plot_single_roc(log_reg, X_eval, y_eval, model_name="Logistic Regression")
# Out:
# Generating Final ROC-AUC Curve for Logistic Regression...

# %% [markdown]
# ### 7. Export Model to the directory

# %%
print("Exporting Logistic Regression pipeline to disk...")
model_path = '../models/neiss_logistic_regression.joblib'
joblib.dump(log_reg, model_path)
print("Model successfully saved!")
# Out:
# Exporting Logistic Regression pipeline to disk...
# Model successfully saved!
